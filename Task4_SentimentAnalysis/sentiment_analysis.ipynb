# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = {
    "Review": [
        "This product is amazing, I love it!",
        "Very bad quality, disappointed",
        "Okay product, not too good not too bad",
        "Excellent service and great experience",
        "Worst purchase ever",
        "I am happy with this item",
        "Not worth the money",
        "Really good and useful product",
        "Terrible experience",
        "Average quality product"
    ]
}

df = pd.DataFrame(data)

df
# Out:
#                                    Review
# 0     This product is amazing, I love it!
# 1          Very bad quality, disappointed
# 2  Okay product, not too good not too bad
# 3  Excellent service and great experience
# 4                     Worst purchase ever
# 5               I am happy with this item
# 6                     Not worth the money
# 7          Really good and useful product
# 8                     Terrible experience
# 9                 Average quality product

# %%
positive_words = ["good", "great", "amazing", "excellent", "love", "happy", "useful"]
negative_words = ["bad", "worst", "terrible", "disappointed", "not worth"]

# %%
def get_sentiment(text):
    text = text.lower()

    pos_count = sum(word in text for word in positive_words)
    neg_count = sum(word in text for word in negative_words)

    if pos_count > neg_count:
        return "Positive"
    elif neg_count > pos_count:
        return "Negative"
    else:
        return "Neutral"

# %%
df["Sentiment"] = df["Review"].apply(get_sentiment)

df
# Out:
#                                    Review Sentiment
# 0     This product is amazing, I love it!  Positive
# 1          Very bad quality, disappointed  Negative
# 2  Okay product, not too good not too bad   Neutral
# 3  Excellent service and great experience  Positive
# 4                     Worst purchase ever  Negative
# 5               I am happy with this item  Positive
# 6                     Not worth the money  Negative
# 7          Really good and useful product  Positive
# 8                     Terrible experience  Negative
# 9                 Average quality product   Neutral

# %%
df["Sentiment"].value_counts()
# Out:
# Sentiment
# Positive    4
# Negative    4
# Neutral     2
# Name: count, dtype: int64

# %%
df["Sentiment"].value_counts().plot(kind="bar")

plt.title("Sentiment Analysis Results")
plt.xlabel("Sentiment")
plt.ylabel("Count")

plt.show()
